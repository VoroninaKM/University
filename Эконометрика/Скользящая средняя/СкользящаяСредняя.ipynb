# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
y_t = pd.read_excel('к лекции 8.xlsx', sheet_name='Данные1')

# %%
# %matplotlib
import matplotlib.pyplot as plt
y_t.plot(x="t", y=['T+E =Yt-St','T скольз'])
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg

# %% [markdown]
# ## Аддитивная модель

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y_t2 = pd.read_excel('к лекции 8.xlsx', sheet_name='Данные2')

# %%
# %matplotlib
y_t2.plot(x="t", y=['TE =Yt/St','T скольз'])
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg

# %% [markdown]
# ## Мультипликативная модель

# %% [markdown]
# ![image.png](attachment:image.png)
